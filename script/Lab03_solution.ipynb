# %% [markdown]
# PLA6619 Introduction to Urban Data and Informatics I \
# Tuesday, September 29, 2020 \
# Week04
#
# # Lab 03
#
# Please submit __Lab02.ipynb with outputs__ on Canvas after this lab session. It doesn't need to be perfect, but your submission will be reflected in attendance and participation. The solution of this notebook will be shared by end of today.
#
# 1. More data manipultation practices with Pandas
# 2. Exploratory data analysis and basic data viz using Matplotlib
#
# ## Resource:
# * Python Data Science Handbook: Essential Tools for Working with Data by Jake VanderPlas (https://jakevdp.github.io/PythonDataScienceHandbook/).
# * Matplotlib resources (https://matplotlib.org/)
# * Python colors (https://matplotlib.org/gallery/color/named_colors.html)

# %% [markdown]
# # Load required packages

# %%
# To ignore unimporant system warnings
import warnings
warnings.filterwarnings("ignore")

# We will use Pandas, Numpy, and Matplotlib which is a package for visualization with Python
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# A magic functin that renders the figure in a notebook 
# %matplotlib inline

# %% [markdown]
# # PART 1. Data preparation

# %% [markdown]
# # 1. Load Datasets
#
# * 'nyc_covid_updated_09272020.csv', NYC COVID-19 data at zipcode level, updated September 27th 2020 (https://github.com/nychealth/coronavirus-data/blob/master/data-by-modzcta.csv)
# * 'nyc_var.csv', NYC zipcode level median income and average household size. The original data source is ACS.
# * FYI, the second data has a duplicate data issue.

# %%
# Load covid-19 data
# If you already know the column information of the dataset, you can specify data type while loading, by using dtype
df_covid = pd.read_csv('../data/nyc_covid_upated_09272020.csv', dtype={'Zipcode':str})
df_covid.head(2)
# Out:
#   Zipcode           NEIGHBORHOOD_NAME BOROUGH_GROUP  COVID_CASE_COUNT  \
# 0   10001  Chelsea/NoMad/West Chelsea     Manhattan               459
# 1   10002   Chinatown/Lower East Side     Manhattan              1372
#
#    COVID_CASE_RATE  POP_DENOMINATOR  COVID_DEATH_COUNT  COVID_DEATH_RATE  \
# 0          1947.97         23563.03                 27            114.59
# 1          1787.50         76755.41                161            209.76
#
#    PERCENT_POSITIVE  TOTAL_COVID_TESTS
# 0              5.47               8395
# 1              6.55              20933

# %%
# Load neighborhood variable data
df_var = pd.read_csv('../data/nyc_var.csv', dtype={'Zipcode':str})
df_var.head(2)
# Out:
#   Zipcode  med_income  avg_hh_size
# 0   10001     88526.0        2.225
# 1   10002     35859.0        2.180

# %% [markdown]
# # 2. Check duplicate data
# * There should not be repeated zipcodes in 'Zipcode' column.
# * Syntax:
#
#        DATAFRAME_NAME.dupliated() --> this returns boolean series with true value for each duplicated row
#        DATAFRAME_NAME.dupliated().sum() --> this returns total number of duplicated rows

# %%
# For the covid data
print (df_covid.duplicated().sum())

# For the variable data
print (df_var.duplicated().sum())
# Out:
# 0
# 7

# %% [markdown]
# # 3. Remove duplicated rows
# * Syntax:
#
#         DATAFRAME_NAME.drop_duplicates()

# %%
print (len(df_var))
df_var = df_var.drop_duplicates()
print (len(df_var))
# Out:
# 184
# 177

# %% [markdown]
# # 4. Join two datasets
# ![title](https://pandas.pydata.org/pandas-docs/stable/_images/merging_merge_on_key.png)
# * We would like to join two tables (df_covid and df_var) based on 'Zipcode' column
# * If you want to learn more about mege, join, or concatenate functions of Pandas, here is a useful link (https://pandas.pydata.org/pandas-docs/stable/user_guide/merging.html)

# %%
df = pd.merge(df_covid, df_var, on='Zipcode', how='left')
df.head(2)
# Out:
#   Zipcode           NEIGHBORHOOD_NAME BOROUGH_GROUP  COVID_CASE_COUNT  \
# 0   10001  Chelsea/NoMad/West Chelsea     Manhattan               459
# 1   10002   Chinatown/Lower East Side     Manhattan              1372
#
#    COVID_CASE_RATE  POP_DENOMINATOR  COVID_DEATH_COUNT  COVID_DEATH_RATE  \
# 0          1947.97         23563.03                 27            114.59
# 1          1787.50         76755.41                161            209.76
#
#    PERCENT_POSITIVE  TOTAL_COVID_TESTS  med_income  avg_hh_size
# 0              5.47               8395     88526.0        2.225
# 1              6.55              20933     35859.0        2.180

# %% [markdown]
# # PART 2. Exploratory Data Analysis
# # 1. Descriptive Statistics

# %%
# .describe is a magic function to print out descriptive statistics of all columns
# .roung() is a function for rounding up
df.describe().round(2)
# Out:
#        COVID_CASE_COUNT  COVID_CASE_RATE  POP_DENOMINATOR  COVID_DEATH_COUNT  \
# count            177.00           177.00           177.00             177.00
# mean            1309.02          2665.78         47425.73             108.07
# std              920.65           934.14         26411.13              86.14
# min               45.00           686.16          3457.77               0.00
# 25%              616.00          1951.58         26614.42              42.00
# 50%             1001.00          2723.96         43030.43              86.00
# 75%             1848.00          3341.25         67089.29             154.00
# max             5168.00          4846.11        111594.10             447.00
#
#        COVID_DEATH_RATE  PERCENT_POSITIVE  TOTAL_COVID_TESTS  med_income  \
# count            177.00            177.00             177.00      177.00
# mean             213.54              9.74           13206.15    73904.98
# std              114.02              3.69            7298.06    36877.85
# min                0.00              2.94            1033.00    21149.00
# 25%              142.25              7.05            7627.00    50832.00
# 50%              205.71             10.30           11759.00    66483.00
# 75%              265.56             12.89           18769.00    88526.00
# max              716.97             15.94           35286.00   250001.00
#
#        avg_hh_size
# count       177.00
# mean          2.64
# std           0.50
# min           1.57
# 25%           2.27
# 50%           2.67
# 75%           2.96
# max           3.97

# %% [markdown]
# # 2. Histogram

# %%
# Default setting
fig = plt.figure(figsize=(6,4))
df['COVID_CASE_RATE'].hist()

# %%
fig = plt.figure(figsize=(6,4)) # width, height in inches
df['COVID_CASE_RATE'].hist(bins=20, color='Gold', edgecolor='k', linewidth=0.5, alpha=0.5)
plt.grid(b=False) # If you make this True, then the gird will be shown

# Plot vertical line (mean)
plt.axvline(df['COVID_CASE_RATE'].mean(), color='black', linewidth=1, linestyle='--', label="Case Rate (Mean)")

#Adjust labeles (x axis and y axis)
plt.ylabel('Number of Neighborhoods', fontsize=13)
plt.xlabel('COVID-19 Case Rate (total cases per 10,000 residents)', fontsize=13)
plt.ylim(0,20)

#Legend, title & export
plt.title('Distribution of COVID-19 cases in New York City \n', fontsize=17)
plt.legend(fontsize=12)

plt.show()# you can disregard this line but if you use plt.show() then just plot part is shown without any processing text

# %% [markdown]
# # 3. Plotting multiple plots at the same time

# %%
plt.figure(figsize=(12,7)) # define your figure

plt.subplot(2,2,1) # first plot of two by two 
df['COVID_CASE_RATE'].hist(bins=30, color='Gold',edgecolor='black', linewidth=0.5, alpha=0.5) # histogram from pandas dataframe
plt.title('COVID-19 case rate in NYC (zipcode level)')
plt.grid(b=False)

plt.subplot(2,2,2) # second plot
df['COVID_DEATH_RATE'].hist(bins=30, color='SteelBlue',edgecolor='black', linewidth=0.5, alpha=0.5) # histogram from pandas dataframe
plt.title('COVID-19 death rate in NYC (zipcode level)')
plt.grid(b=False)

plt.subplot(2,2,3) # third plot
df['PERCENT_POSITIVE'].hist(bins=30, color='forestgreen',edgecolor='black', linewidth=0.5, alpha=0.5) # histogram from pandas dataframe
plt.title('COVID-19 positivity rate in NYC (zipcode level)')
plt.grid(b=False)

plt.subplot(2,2,4) # fourth plot
df['TOTAL_COVID_TESTS'].hist(bins=30, color='salmon',edgecolor='black', linewidth=0.5, alpha=0.5) # histogram from pandas dataframe
plt.title('COVID-19 total tests in NYC (zipcode level)')
plt.grid(b=False)

# %% [markdown]
# # 4. Scatter plot
# * Syntax:
#
#         plt.scatter(DATAFRAME['COLUMN1'],DATAFRAME['COLUMN2'])

# %%
fig = plt.figure(figsize=(6,6))
plt.scatter(df['avg_hh_size'], df['COVID_CASE_RATE'], s=10, c='Navy')

plt.xlabel('Average household size at zipcode level', fontsize=13)
plt.ylabel('COVID-19 case rate at zipcode level', fontsize=13)
# Out:
# Text(0, 0.5, 'COVID-19 case rate at zipcode level')

# %% [markdown]
# # 5. Correlation plots (scatter matrix plots) and correlation test
#
# Compute pairwise correlation of columns, excluding NA/null values
#
# Method of correlation
# * pearson : standard correlation coefficient (Default)
# * kendall : Kendall Tau correlation coefficient
# * spearman : Spearman rank correlation

# %%
from pandas.plotting import scatter_matrix

# %%
scatter_matrix(df[['COVID_CASE_RATE','COVID_DEATH_RATE', 'PERCENT_POSITIVE', 'med_income', 'avg_hh_size']], 
               figsize=(12,12), hist_kwds={'color':'Navy', 'edgecolor':'k', 'alpha':0.5},
              s=13, color='Navy')
plt.show()

# %%
df[['COVID_CASE_RATE','COVID_DEATH_RATE', 'PERCENT_POSITIVE', 'med_income', 'avg_hh_size']].corr()
# Out:
#                   COVID_CASE_RATE  COVID_DEATH_RATE  PERCENT_POSITIVE  \
# COVID_CASE_RATE          1.000000          0.747249          0.914193
# COVID_DEATH_RATE         0.747249          1.000000          0.640988
# PERCENT_POSITIVE         0.914193          0.640988          1.000000
# med_income              -0.582464         -0.533744         -0.590667
# avg_hh_size              0.607544          0.338057          0.798336
#
#                   med_income  avg_hh_size
# COVID_CASE_RATE    -0.582464     0.607544
# COVID_DEATH_RATE   -0.533744     0.338057
# PERCENT_POSITIVE   -0.590667     0.798336
# med_income          1.000000    -0.442820
# avg_hh_size        -0.442820     1.000000

# %% [markdown]
# # 6. Heatmap

# %%
import seaborn as sns # useful data viz package with Matplotlib

# %%
# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(13, 2))

# plot the heatmap and annotation on it
sns.heatmap(df.corr(), cmap='bwr', linewidth=1, alpha=0.7)

# %%
# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(13, 2))

# Generate a mask for the upper triangle
mask = np.zeros_like(df.corr(), dtype=np.bool)
mask[np.triu_indices_from(mask)] = True # Mark 'true' for the upper-triangle 

# plot the heatmap and annotation on it
sns.heatmap(df.corr(), cmap='bwr', linewidth=1, alpha=0.7, mask=mask)

# %% [markdown]
# # 7. Line plot (be applicable to timeseries)
# * X-axis is based on the index of the dataframe

# %%
# set the index of the dataframe (zipcode)
df.index = df['Zipcode']
df.head(2)
# Out:
#         Zipcode           NEIGHBORHOOD_NAME BOROUGH_GROUP  COVID_CASE_COUNT  \
# Zipcode
# 10001     10001  Chelsea/NoMad/West Chelsea     Manhattan               459
# 10002     10002   Chinatown/Lower East Side     Manhattan              1372
#
#          COVID_CASE_RATE  POP_DENOMINATOR  COVID_DEATH_COUNT  \
# Zipcode
# 10001            1947.97         23563.03                 27
# 10002            1787.50         76755.41                161
#
#          COVID_DEATH_RATE  PERCENT_POSITIVE  TOTAL_COVID_TESTS  med_income  \
# Zipcode
# 10001              114.59              5.47               8395     88526.0
# 10002              209.76              6.55              20933     35859.0
#
#          avg_hh_size
# Zipcode
# 10001          2.225
# 10002          2.180

# %%
fig = plt.figure(figsize=(16,5))
plt.plot(df['COVID_CASE_RATE'], color='crimson', marker='o', markersize=4)

# Specify x-axis ticks
plt.xticks(range(len(df))[::5], df['Zipcode'].tolist()[::5], rotation=90)
plt.grid(color='grey', alpha=0.3)
plt.show()

# %% [markdown]
# # 8. Bar charts (using groupby)
# * Basic syntax to plot a bar chart is
#
#         plt.bar(keys, values)

# %%
df_boro = df.groupby('BOROUGH_GROUP').mean().reset_index()
df_boro.head()
# Out:
#    BOROUGH_GROUP  COVID_CASE_COUNT  COVID_CASE_RATE  POP_DENOMINATOR  \
# 0          Bronx       2085.240000      3620.855200     57387.706000
# 1       Brooklyn       1735.837838      2449.586486     69806.215946
# 2      Manhattan        676.590909      1746.797727     36635.079318
# 3         Queens       1188.305085      2962.868814     38791.691864
# 4  Staten Island       1288.250000      3251.510833     39681.584167
#
#    COVID_DEATH_COUNT  COVID_DEATH_RATE  PERCENT_POSITIVE  TOTAL_COVID_TESTS  \
# 0         160.400000        274.262800         12.500400       16463.000000
# 1         153.405405        225.319189          9.417838       18295.783784
# 2          57.295455        138.560682          5.599773       11772.386364
# 3         102.000000        243.388475         11.368305       10203.372881
# 4          75.250000        178.931667         12.124167       10748.833333
#
#       med_income  avg_hh_size
# 0   43566.560000     2.761200
# 1   60649.324324     2.673243
# 2  104179.363636     2.096705
# 3   71888.994350     2.927232
# 4   76887.500000     2.832500

# %%
plt.bar(df_boro['BOROUGH_GROUP'], df_boro['COVID_CASE_RATE'], )
plt.xlabel('Borough')
plt.ylabel('Average neighborhood Covid-19 case rate')
# Out:
# Text(0, 0.5, 'Average neighborhood Covid-19 case rate')

# %%
plt.barh(df_boro['BOROUGH_GROUP'], df_boro['COVID_CASE_RATE'], )
plt.xlabel('Borough')
plt.ylabel('Average neighborhood Covid-19 case rate')
# Out:
# Text(0, 0.5, 'Average neighborhood Covid-19 case rate')
