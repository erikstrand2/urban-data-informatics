# %%
import pandas as pd
import numpy as np

# %%
calls = pd.read_csv("../data/NYC_311_subset.csv")
# Out:
# /Users/erik_strand/opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (8,17,31,34) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
calls.head()
# Out:
#    Unique Key            Created Date             Closed Date Agency  \
# 0    41316662  01/01/2019 12:00:00 AM  01/02/2019 12:00:00 AM  DOHMH
# 1    41316968  01/01/2019 12:00:00 AM  01/15/2019 04:28:53 PM  DOHMH
# 2    41318587  01/01/2019 12:00:00 AM  01/01/2019 12:00:00 AM  DOHMH
# 3    41309122  01/01/2019 12:00:00 AM  01/10/2019 12:00:00 AM  DOHMH
# 4    41310910  01/01/2019 12:00:00 AM  01/01/2019 12:00:00 AM  DOHMH
#
#                                Agency Name Complaint Type      Descriptor  \
# 0  Department of Health and Mental Hygiene         Rodent    Rat Sighting
# 1  Department of Health and Mental Hygiene         Rodent    Rat Sighting
# 2  Department of Health and Mental Hygiene         Rodent    Rat Sighting
# 3  Department of Health and Mental Hygiene         Rodent  Mouse Sighting
# 4  Department of Health and Mental Hygiene         Rodent    Rat Sighting
#
#              Location Type Incident Zip          Incident Address  ...  \
# ...

# %%
calls.columns.tolist()
# Out:
# ['Unique Key',
#  'Created Date',
#  'Closed Date',
#  'Agency',
#  'Agency Name',
#  'Complaint Type',
#  'Descriptor',
#  'Location Type',
#  'Incident Zip',
#  'Incident Address',
#  'Street Name',
#  'Cross Street 1',
#  'Cross Street 2',
#  'Intersection Street 1',
#  'Intersection Street 2',
#  'Address Type',
#  'City',
#  'Landmark',
#  'Facility Type',
#  'Status',
#  'Due Date',
#  'Resolution Description',
#  'Resolution Action Updated Date',
#  'Community Board',
#  'BBL',
#  'Borough',
#  'X Coordinate (State Plane)',
#  'Y Coordinate (State Plane)',
#  'Open Data Channel Type',
#  'Park Facility Name',
#  'Park Borough',
#  'Vehicle Type',
#  'Taxi Company Borough',
#  'Taxi Pick Up Location',
#  'Bridge Highway Name',
#  'Bridge Highway Direction',
#  'Road Ramp',
#  'Bridge Highway Segment',
#  'Latitude',
#  'Longitude',
#  'Location']

# %%
calls['Unique Key'].count()
# Out:
# 2456125

# %%
calls[['Created Date', 'Agency', 'Complaint Type', 'Status', 'Borough']].head(15)
# Out:
#               Created Date Agency               Complaint Type  Status  \
# 0   01/01/2019 12:00:00 AM  DOHMH                       Rodent  Closed
# 1   01/01/2019 12:00:00 AM  DOHMH                       Rodent  Closed
# 2   01/01/2019 12:00:00 AM  DOHMH                       Rodent  Closed
# 3   01/01/2019 12:00:00 AM  DOHMH                       Rodent  Closed
# 4   01/01/2019 12:00:00 AM  DOHMH                       Rodent  Closed
# 5   01/01/2019 12:00:00 AM  DOHMH                       Rodent  Closed
# 6   01/01/2019 12:00:00 AM  DOHMH                       Rodent  Closed
# 7   01/01/2019 12:00:00 AM  DOHMH  Unsanitary Pigeon Condition  Closed
# 8   01/01/2019 12:00:00 AM  DOHMH                       Rodent  Closed
# 9   01/01/2019 12:00:00 AM  DOHMH  Unsanitary Pigeon Condition  Closed
# 10  01/01/2019 12:00:00 AM  DOHMH                       Rodent  Closed
# 11  01/01/2019 12:00:00 AM  DOHMH                       Rodent  Closed
# ...

# %%
print(calls['Agency'].unique())
print(calls['Agency'].nunique())
print(calls['Agency'].value_counts())
# Out:
# ['DOHMH' 'HPD' 'NYPD' 'TLC' 'DOT' 'DEP' 'DSNY' 'DOB' 'DPR' 'HRA' 'DCA'
#  'DHS' 'DOF' 'DFTA' 'EDC' 'DOITT' 'DCAS' 'DOE' 'ACS' 'TAX' 'NYCEM' 'DCP'
#  'MOC' 'TAT' 'COIB' 'DVS' 'FDNY']
# 27
# NYPD     840882
# HPD      465672
# DSNY     283510
# DOT      281864
# DEP      180227
# DOB      124956
# DPR      102918
# DOHMH     64426
# TLC       39271
# DOF       21936
# DHS       21059
# DCA       14923
# HRA        4555
# DFTA       3614
# EDC        3332
# DOE        1529
# DOITT       474
# DCAS        441
# ACS         193
# TAX         152
# DVS         123
# NYCEM        44
# DCP          14
# TAT           4
# COIB          4
# FDNY          1
# MOC           1
# Name: Agency, dtype: int64

# %%
print(calls.groupby(by = 'Borough')['Unique Key'].count())
print(calls.groupby(by = 'Borough')['Status'].value_counts())
# Out:
# Borough
# BRONX            439094
# BROOKLYN         772368
# MANHATTAN        488027
# QUEENS           605305
# STATEN ISLAND    129122
# Unspecified       22209
# Name: Unique Key, dtype: int64
# Borough        Status
# BRONX          Closed         427216
#                In Progress      5164
#                Pending          4507
#                Open             1816
#                Assigned          297
#                Started            94
# BROOKLYN       Closed         742549
#                In Progress     17408
#                Pending          6818
#                Open             3996
#                Started           928
#                Assigned          669
# MANHATTAN      Closed         464440
#                In Progress     17597
#                Pending          2735
#                Open             2210
#                Assigned          558
#                Started           486
#                Unspecified         1
# ...

# %%
print(calls['Borough'].unique())
print(calls['Borough'].value_counts())
# Out:
# ['QUEENS' 'BROOKLYN' 'BRONX' 'MANHATTAN' 'STATEN ISLAND' 'Unspecified']
# BROOKLYN         772368
# QUEENS           605305
# MANHATTAN        488027
# BRONX            439094
# STATEN ISLAND    129122
# Unspecified       22209
# Name: Borough, dtype: int64

# %%
print(calls['Complaint Type'].value_counts())
# Out:
# Noise - Residential                    232853
# HEAT/HOT WATER                         212074
# Illegal Parking                        198345
# Blocked Driveway                       137732
# Request Large Bulky Item Collection     99538
#                                         ...
# ...\./...\./...\./...\./......              1
# Misc. Comments' and 7702=77...              1
# Misc. Comments'|echo y9v6fc...              1
# Misc. Comments'+(function()...              1
# Stalled Sites                               1
# Name: Complaint Type, Length: 367, dtype: int64

# %%
print(calls['Complaint Type'].nunique())
print(calls.groupby(by = 'Borough')['Complaint Type'].value_counts().groupby(by = 'Borough').head())
# Out:
# 367
# Borough        Complaint Type
# BRONX          HEAT/HOT WATER                         70328
#                Noise - Residential                    57131
#                Noise - Street/Sidewalk                24741
#                Blocked Driveway                       24254
#                Illegal Parking                        22192
# BROOKLYN       Illegal Parking                        69534
#                Noise - Residential                    67184
#                HEAT/HOT WATER                         63291
#                Blocked Driveway                       50289
#                Request Large Bulky Item Collection    36352
# MANHATTAN      Noise - Residential                    50397
#                HEAT/HOT WATER                         47490
#                Noise - Street/Sidewalk                35214
#                Illegal Parking                        32753
#                Noise                                  25043
# ...

# %%
print(calls[(calls['Complaint Type'] == 'HEAT/HOT WATER')].groupby(by = 'Borough')['Complaint Type'].value_counts())
# Out:
# Borough        Complaint Type
# BRONX          HEAT/HOT WATER    70328
# BROOKLYN       HEAT/HOT WATER    63291
# MANHATTAN      HEAT/HOT WATER    47490
# QUEENS         HEAT/HOT WATER    28874
# STATEN ISLAND  HEAT/HOT WATER     2091
# Name: Complaint Type, dtype: int64
